# %%
# Source: https://www.kaggle.com/datasets/nelgiriyewithana/countries-of-the-world-2023
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("world-data-2023.csv")
df.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions  ... Out of pocket health expenditure  \
# 0              Kabul         8,672  ...                           78.40%
# ...

# %%
describe_df = df.describe()
describe_df.to_csv("describe_df.csv")
pd.read_csv("describe_df.csv")
# Out:
#   Unnamed: 0  Birth Rate  Calling Code  Fertility Rate  Infant mortality  \
# 0      count  189.000000    194.000000      188.000000        189.000000
# 1       mean   20.214974    360.546392        2.698138         21.332804
# 2        std    9.945774    323.236419        1.282267         19.548058
# 3        min    5.900000      1.000000        0.980000          1.400000
# 4        25%   11.300000     82.500000        1.705000          6.000000
# 5        50%   17.950000    255.500000        2.245000         14.000000
# 6        75%   28.750000    506.750000        3.597500         32.700000
# 7        max   46.080000   1876.000000        6.910000         84.500000
#
#    Life expectancy  Maternal mortality ratio  Physicians per thousand  \
# 0       187.000000                181.000000               188.000000
# 1        72.279679                160.392265                 1.839840
# 2         7.483661                233.502024                 1.684261
# ...

# %%
df[df["Birth Rate"] == df["Birth Rate"].max()]
# Out:
#     Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 125   Niger               19           NE                36.10%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 125      1,267,000            10,000       46.08         227.0
#
#     Capital/Major City Co2-Emissions  ... Out of pocket health expenditure  \
# 125             Niamey         2,017  ...                           52.30%
#
#     Physicians per thousand  Population  \
# 125                    0.04  23,310,715
#
#      Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 125                                     72.00%          11.80%         47.20%
#
#     Unemployment rate Urban_population   Latitude  Longitude
# 125             0.47%        3,850,231  17.607789   8.081666
#
# [1 rows x 35 columns]

# %%
df[df["Birth Rate"] == df["Birth Rate"].min()]
# Out:
#     Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 113  Monaco           26,337           MC                   NaN
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 113              2               NaN         5.9         377.0
#
#     Capital/Major City Co2-Emissions  ... Out of pocket health expenditure  \
# 113        Monaco City           NaN  ...                            6.10%
#
#     Physicians per thousand Population  \
# 113                    6.56     38,964
#
#      Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 113                                        NaN             NaN            NaN
#
#     Unemployment rate Urban_population   Latitude  Longitude
# 113               NaN           38,964  43.738418   7.424616
#
# [1 rows x 35 columns]

# %%
statistics_birth_rate = df["Birth Rate"].head()
statistics_agricultural_land = df["Agricultural Land( %)"].head()
 
plt.ylabel("Agricultural Land( %)")
plt.xlabel("Birth Rate")
plt.plot(statistics_birth_rate,statistics_agricultural_land,color='#008840',marker='+',linestyle='--',markersize=20,label="Birth Rate and Agricultural Land( %)")

plt.legend(loc='best',shadow=True,fontsize='small')

plt.savefig("Agricultural_Land_and_Birt_Rate.png",bbox_inches="tight",transparent=True)

# %%
df["Birth Rate"].head()
# Out:
# 0    32.49
# 1    11.78
# 2    24.28
# 3     7.20
# 4    40.73
# Name: Birth Rate, dtype: float64

# %%
statistics_latitude = df["Latitude"].head()
statistics_longitude = df["Longitude"].head()

plt.ylabel("Value")
plt.xlabel("People")
plt.plot(statistics_latitude,'rD--',label="Latitude")
plt.plot(statistics_longitude,'bD--',label="Longitude")

plt.legend(loc='upper right',shadow=True,fontsize='large')
plt.savefig("latitude_logitude.png", bbox_inches="tight",pad_inches=2,transparent=True)

# %%
# %whos
# Out:
# Variable                       Type         Data/Info
# -----------------------------------------------------
# describe_df                    DataFrame           Birth Rate  Callin<...>  64.963051  178.065032
# df                             DataFrame             Country Density\<...>\n[195 rows x 35 columns]
# np                             module       <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# pd                             module       <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# plt                            module       <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# statistics_agricultural_land   Series       0    58.10%\n1    43.10%\<...>l Land( %), dtype: object
# statistics_birth_rate          Series       0    32.49\n1    11.78\n2<...>irth Rate, dtype: float64
# statistics_latitude            Series       0    33.939110\n1    41.1<...> Latitude, dtype: float64
# ...
