# %%
# Source: https://www.kaggle.com/datasets/mrcalvinwhite/technology-perception-survey
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Dataset - Factors Influencing Technology Adoption in Consumer Households.csv")
df.head()
# Out:
#    Age  Gender     EducationLevel  HouseholdIncome  Frequency_LaptopDesktop  \
# 0   25  Female  Bachelor's Degree        1500000.0                        4
# 1   48  Female  Bachelor's Degree         800000.0                        3
# 2   49    Male    Master's Degree       30000000.0                        4
# 3   38    Male  Bachelor's Degree          20000.0                        1
# 4   45    Male  Bachelor's Degree        5000000.0                        5
#
#    Frequency_Smartphone  Frequency_Tablet  Frequency_SmartHomeDevices  \
# 0                     5                 0                           4
# 1                     5                 5                           4
# 2                     4                 0                           2
# 3                     0                 1                           1
# 4                     5                 3                           5
#
#    Frequency_WearableDevices  Frequency_GamingConsoles  ...  \
# ...

# %%
df_names = np.array(["Frequency_LaptopDesktop","Frequency_Smartphone"])
df_things = np.array([df["Frequency_LaptopDesktop"].head(1),
                      df["Frequency_Smartphone"].head(1)])
df_things = df_things.ravel()

plt.axis("equal")
plt.pie(df_things,labels=df_names,autopct="%0.2f%%",shadow=True,explode=[0.2,0])
plt.savefig("pie.png", bbox_inches="tight",pad_inches=1.5,transparent=True)
