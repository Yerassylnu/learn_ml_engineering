# %%
# Source:https://www.kaggle.com/datasets/vstacknocopyright/magic-telescope-dataset
import pandas as pd
import numpy as np
df = pd.read_csv("MagicTelescope.csv")
df.head()
# Out:
#    id  ID  fLength:   fWidth:  fSize:  fConc:  fConc1:    fAsym:  fM3Long:  \
# 0   1   1   28.7967   16.0021  2.6449  0.3918   0.1982   27.7004   22.0110
# 1   2   2   31.6036   11.7235  2.5185  0.5303   0.3773   26.2722   23.8238
# 2   3   3  162.0520  136.0310  4.0612  0.0374   0.0187  116.7410  -64.8580
# 3   4   4   23.8172    9.5728  2.3385  0.6147   0.3922   27.2107   -6.4633
# 4   5   5   75.1362   30.9205  3.1611  0.3168   0.1832   -5.5277   28.5525
#
#    fM3Trans:  fAlpha:    fDist: class:
# 0    -8.2027  40.0920   81.8828      g
# 1    -9.9574   6.3609  205.2610      g
# 2   -45.2160  76.9600  256.7880      g
# 3    -7.1513  10.4490  116.7370      g
# 4    21.8393   4.6480  356.4620      g

# %%
rows,columns = df.shape

print("Количество строк:",rows)
print("Количество столбцов:",columns)
# Out:
# Количество строк: 19020
# Количество столбцов: 13

# %%
describe1 = df.describe()
describe1
# Out:
#                  id            ID      fLength:       fWidth:        fSize:  \
# count  19020.000000  19020.000000  19020.000000  19020.000000  19020.000000
# mean    9510.500000   9510.500000     53.250154     22.180966      2.825017
# std     5490.745396   5490.745396     42.364855     18.346056      0.472599
# min        1.000000      1.000000      4.283500      0.000000      1.941300
# 25%     4755.750000   4755.750000     24.336000     11.863800      2.477100
# 50%     9510.500000   9510.500000     37.147700     17.139900      2.739600
# 75%    14265.250000  14265.250000     70.122175     24.739475      3.101600
# max    19020.000000  19020.000000    334.177000    256.382000      5.323300
#
#              fConc:       fConc1:        fAsym:      fM3Long:     fM3Trans:  \
# count  19020.000000  19020.000000  19020.000000  19020.000000  19020.000000
# mean       0.380327      0.214657     -4.331745     10.545545      0.249726
# ...

# %%
describe2 = np.around(describe1, decimals=2, out=None)
describe2
# Out:
#              id        ID  fLength:   fWidth:    fSize:    fConc:   fConc1:  \
# count  19020.00  19020.00  19020.00  19020.00  19020.00  19020.00  19020.00
# mean    9510.50   9510.50     53.25     22.18      2.83      0.38      0.21
# std     5490.75   5490.75     42.36     18.35      0.47      0.18      0.11
# min        1.00      1.00      4.28      0.00      1.94      0.01      0.00
# 25%     4755.75   4755.75     24.34     11.86      2.48      0.24      0.13
# 50%     9510.50   9510.50     37.15     17.14      2.74      0.35      0.20
# 75%    14265.25  14265.25     70.12     24.74      3.10      0.50      0.29
# max    19020.00  19020.00    334.18    256.38      5.32      0.89      0.68
#
#          fAsym:  fM3Long:  fM3Trans:   fAlpha:    fDist:
# count  19020.00  19020.00   19020.00  19020.00  19020.00
# mean      -4.33     10.55       0.25     27.65    193.82
# std       59.21     51.00      20.83     26.10     74.73
# ...
